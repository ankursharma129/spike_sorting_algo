# %%
import sys
import math

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_file = "example_data.csv"
row_to_plot = 1

# %%
with open(csv_file, 'r') as f:
    original_data = f.read().split('\n')[1:]
    original_data = original_data[row_to_plot].split(',')
    spike_positions = [int(x) for x in original_data[1].split(';')]
    samples = [int(x) for x in original_data[0].split(';')]

    
print(samples[:100])
print(spike_positions[:100])
# To plot the spikes, generate an array of NaNs (which do not get plotted)
spikes = [math.nan] * len(samples)

# Plot spike indicators above all samples.
spike_y = max(samples) + 1

# Replace the values in the positions of the spikes with the maximum sample value
for s in spike_positions:
    spikes[s] = spike_y

# Generate the time vector (fs=20kHz)
t = [x/20000 for x in range(len(samples))]

# plt.plot(t, samples)
# plt.plot(t, spikes, 'v')
# plt.show()
# Out:
# [-137, -130, -115, -105, -94, -79, -65, -63, -73, -85, -93, -99, -102, -100, -92, -84, -77, -73, -71, -74, -78, -83, -91, -100, -109, -119, -129, -132, -127, -121, -119, -119, -116, -111, -109, -108, -110, -110, -109, -110, -114, -120, -123, -126, -132, -142, -152, -161, -168, -175, -180, -182, -181, -179, -174, -167, -159, -151, -143, -134, -128, -127, -132, -134, -130, -123, -116, -109, -103, -100, -103, -111, -118, -119, -116, -116, -119, -126, -139, -151, -155, -155, -154, -147, -130, -115, -113, -112, -104, -98, -101, -104, -95, -81, -74, -73, -71, -68, -71, -79]
# [898, 991, 1060, 1510, 1930, 2065, 2477, 3235, 3402, 3685, 3732, 3854, 4333, 4407, 4459, 4634, 4700, 4780, 5715, 5731, 5911, 6215, 6350, 6658, 7040, 7242, 7589, 8390, 9110, 9260, 9472, 10100, 10507, 10608, 10641, 11341, 11413, 11843, 12645, 14830, 16550, 17202, 17435, 17572, 17762, 18246, 19128, 19260, 20034, 20526, 20618, 20705, 20834, 21655, 22045, 22522, 22603, 23040, 23571, 23589, 23672, 23707, 23745, 24426, 25398, 26249, 26477, 26510, 26630, 26837, 27277, 27668, 27774, 28881, 29640, 30856, 30947, 31365, 31510, 31810, 31841, 31871, 31950, 32125, 32172, 32276, 32298, 32378, 32990, 33369, 33470, 33961, 34070, 35160, 35850, 36037, 36133, 36561, 36666, 36834]

# %%
plt.plot(t[800:1000], samples[800:1000])
plt.plot(t[800:1000], spikes[800:1000], 'v')
plt.show()

# %%
plt.plot(t, samples)

# %%
from scipy.signal import butter, sosfiltfilt
from scipy.fft import fft, fftfreq

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b = butter(order, [low, high], btype='band', output='sos')
    return b

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b= butter_bandpass(lowcut, highcut, fs, order=order)
    plt.plot(b)
    plt.show()
    y = sosfiltfilt(b, data)
    return y

def butter_lowpass(freq, fs, order=5):
    nyq = 0.5 * fs
    freq = freq / nyq
    b = butter(order, freq, btype='low', output='sos')
    return b

def butter_lowpass_filter(data, freq, fs, order=5):
    b= butter_lowpass(freq, fs, order=order)
    plt.plot(b)
    plt.show()
    y = sosfiltfilt(b, data)
    return y

# %%
filtered = butter_lowpass_filter(samples, 50, 20000, order=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jr/f2jcthz95pl7fq_94vdr9jdh0000gn/T/ipykernel_45543/3730069223.py in <module>
# ----> 1 filtered = butter_lowpass_filter(samples, 50, 20000, order=2)
#
# /var/folders/jr/f2jcthz95pl7fq_94vdr9jdh0000gn/T/ipykernel_45543/80445217.py in butter_lowpass_filter(data, freq, fs, order)
#      23
#      24 def butter_lowpass_filter(data, freq, fs, order=5):
# ---> 25     b= butter_bandpass(freq, fs, order=order)
#      26     plt.plot(b)
#      27     plt.show()
#
# TypeError: butter_bandpass() missing 1 required positional argument: 'fs'

# %%
plt.plot(t, filtered)
